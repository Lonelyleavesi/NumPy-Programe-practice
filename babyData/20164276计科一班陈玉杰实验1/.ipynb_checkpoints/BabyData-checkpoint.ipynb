# %% [markdown]
# ### 先创造一个文本列表用于储存年份文本

# %%
yearslist = {}  #用以年份为key 文档名为value 的字典会更好？
begin = 1880
end = 2010 + 1

for x in range(end - begin):
    tempstr = "babynames\yob"+str(begin+x)+".txt";
    yearslist[str(begin+x)] = tempstr
#yearslist 中保存了所有babyname文档的名字 方便以后导入

# %% [markdown]
# ## 第1.2问读取姓名数据，存储为Pandas的DataFrame； 输入姓名、年份，输出该姓名在该年份的出生人数；

# %%
import numpy as np
from pandas import DataFrame, Series
import pandas as pd
year1 = input("请输入一个年份 ： ") 
path = np.loadtxt(yearslist[year1],delimiter = "," , usecols=(0,1,2) , dtype=str) #用字典的方法 通过year1 的文本读取此文件 默认数据类型都为str
babyframe = DataFrame(path,columns=['Name','sex','Num'])  #转化成为DataFrame
babyframe['Num']=babyframe['Num'].astype(np.int32)   #babyframe 的Num列从str转化为 int32 
babyframe
# Out:
# 请输入一个年份 ： 1880
#            Name sex   Num
# 0          Mary   F  7065
# 1          Anna   F  2604
# 2          Emma   F  2003
# 3     Elizabeth   F  1939
# 4        Minnie   F  1746
# 5      Margaret   F  1578
# 6           Ida   F  1472
# 7         Alice   F  1414
# 8        Bertha   F  1320
# 9         Sarah   F  1288
# 10        Annie   F  1258
# 11        Clara   F  1226
# 12         Ella   F  1156
# 13     Florence   F  1063
# 14         Cora   F  1045
# 15       Martha   F  1040
# 16        Laura   F  1012
# 17       Nellie   F   995
# 18        Grace   F   982
# 19       Carrie   F   949
# 20        Maude   F   858
# 21        Mabel   F   808
# 22       Bessie   F   794
# 23       Jennie   F   793
# 24     Gertrude   F   787
# 25        Julia   F   783
# 26       Hattie   F   769
# 27        Edith   F   768
# 28       Mattie   F   704
# 29         Rose   F   700
# ...         ...  ..   ...
# 1970      Philo   M     5
# 1971    Phineas   M     5
# 1972    Presley   M     5
# 1973     Ransom   M     5
# 1974      Reece   M     5
# 1975       Rene   M     5
# 1976    Roswell   M     5
# 1977    Rowland   M     5
# 1978    Sampson   M     5
# 1979     Samual   M     5
# 1980     Santos   M     5
# 1981   Schuyler   M     5
# 1982   Sheppard   M     5
# 1983   Spurgeon   M     5
# 1984   Starling   M     5
# 1985   Sylvanus   M     5
# 1986   Theadore   M     5
# 1987  Theophile   M     5
# 1988     Tilmon   M     5
# 1989      Tommy   M     5
# 1990    Unknown   M     5
# 1991       Vann   M     5
# 1992        Wes   M     5
# 1993    Winston   M     5
# 1994       Wood   M     5
# 1995     Woodie   M     5
# 1996     Worthy   M     5
# 1997     Wright   M     5
# 1998       York   M     5
# 1999  Zachariah   M     5
#
# [2000 rows x 3 columns]

# %%
def get_counts(frame,name):   #定义一个用于统计姓名的方法
    counts = {}
    t_frame = frame.loc[frame['Name'] == name]    #锁定姓名等于name的 一列
    counts[name] = t_frame.iloc[:,2].sum()
    return counts

# %%
babyname = input("请输入一个婴儿的名字 ： ")
counts = get_counts(babyframe,babyname)
print("姓名为",babyname,"的人数为",counts[babyname])
# Out:
# 请输入一个婴儿的名字 ： Anna
# 姓名为 Anna 的人数为 2616

# %% [markdown]
# ## 第三问 输入姓名、开始年份和结束年份，绘制该姓名在各年份出生人数折线图；

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = input("请输入一个结束年份 ")
years = range(int(begin), int(end))

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1880
# 请输入一个结束年份 2000

# %% [markdown]
# ### 通过姓名取得一个小 DataFrame

# %%
name = input("请输入一个姓名 ： ")
t_frame = babyframe.loc[babyframe['Name'] == name]
# Out:
# 请输入一个姓名 ： Anna

# %% [markdown]
# ### 对不同性别的人 求和，取得一个只有年份与人数的Series

# %%
a = t_frame.groupby('year').births.sum()  
a.name = name
b = DataFrame(a)  #转化为DataFrame

# %% [markdown]
# ### 用pandas 自带的plot 对这个DataFrame画图

# %%
b.plot(label="bb",kind='line', rot=0)

# %% [markdown]
# ### 利用matplotlib API画图

# %%
import matplotlib.pyplot as plt  #利用matplotlib API画图
fig = plt.figure()             #创立figure对象 储存位图
ax = fig.add_subplot(1,1,1)   #添加一个位图  一共有1x1个位图 这是第1个位图
plt.plot(b,'k-',label = name) #画出第一个线 b中提取数据  标签为name
ax.set_title('years-num')   #设置标题 以及x，y轴名称
ax.set_xlabel('years')
ax.set_ylabel('num')
# Out:
# Text(0,0.5,'num')

# %% [markdown]
# ## 第四问. 输入若干姓名、开始年份和结束年份，绘制这些姓名在对应年份区间的出生总人数的条状图；

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = input("请输入一个结束年份 ")
years = range(int(begin), int(end))

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1880
# 请输入一个结束年份 1885

# %% [markdown]
# ### 创建用于储存若干姓名的list 且输入若干姓名后 输入Q退出

# %%
Names = []  #用于储存若干姓名的list
name = ''
print("输入若干姓名并且输入Q为退出。")
while(name != 'Q'):                      
    name = input("输入姓名： ")   
    Names.append(name);
Names.pop()            #删除最后一位元素 'Q'
Names
# Out:
# 输入若干姓名并且输入Q为退出。
# 输入姓名： Anna
# 输入姓名： Q
# ['Anna']

# %% [markdown]
# ### #与上面相似 但是由于是多个DataFrame 需通过字典储存每一个小DataFrame

# %%
t_frames = {}
for t_name in Names:
    t_frame = babyframe.loc[babyframe['Name'] == t_name]  #一个小的frame
    t_frames[t_name] = t_frame  #通过姓名存入一个小的frame

# %%
a = {}  #与第二题画图一样 不过a 与b  都成为字典
b = {}
for key, v in t_frames.items():      #其中key 是名称 V是字典里存的Series
    a[key] = v.groupby('year').births.sum()  #对不同性别的人 求和，取得一个只有年份与人数的Series
    a[key].name = key+'_num'
    b[key] = DataFrame(a[key])  #转化为DataFrame
b
# Out:
# {'Anna':       Anna_num
#  year
#  1880      2616
#  1881      2714
#  1882      3143
#  1883      3322
#  1884      3880}

# %%
pieces = []   #用一个列表保存需要合并的DataFrame
for key,v in b.items():   
    pieces.append(v)
result=pd.concat(pieces,sort=True,axis=1)  #合并Frame  注意axis = 1   
result.plot(kind = 'bar',style = 'k--')

# %%
#同上
fig = plt.figure()             #创立figure对象 储存位图
ax = fig.add_subplot(1,1,1)   #添加一个位图  一共有1x1个位图 这是第1个位图
for key,v in b.items():
    plt.plot(v,label = key) #画出第一个线 b中提取数据  标签为name
ax.set_title('years-num')   #设置标题 以及x，y轴名称
ax.set_xlabel('years')
ax.set_ylabel('num')
ax.legend(loc = 'best')

# %% [markdown]
# ## 第五问 输入姓名、开始年份、结束年份、人口预期寿命，绘制该姓名在各年份生存人数折线图；

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = input("请输入一个结束年份 ")
years = range(int(begin), int(end))

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1880
# 请输入一个结束年份 2000

# %%
Life_expectancy = input("请输入人口预期寿命 ：")
name = input("请输入一个姓名 ： ")
t_frame = babyframe.loc[babyframe['Name'] == name]  #通过姓名取得一个小 DataFrame
# Out:
# 请输入人口预期寿命 ：60
# 请输入一个姓名 ： Anna

# %%
a = t_frame.groupby('year').births.sum()  #对不同性别的人 求和，取得一个只有年份与人数的Series
a.name = name
b = DataFrame(a)  #转化为DataFrame
b
# Out:
#       Anna
# year
# 1880  2616
# 1881  2714
# 1882  3143
# 1883  3322
# 1884  3880
# 1885  4014
# 1886  4298
# 1887  4239
# 1888  5008
# 1889  5085
# 1890  5253
# 1891  5114
# 1892  5562
# 1893  5712
# 1894  5585
# 1895  5967
# 1896  5877
# 1897  5448
# 1898  5804
# 1899  5138
# 1900  6140
# 1901  4941
# 1902  5304
# 1903  5116
# 1904  5346
# 1905  5445
# 1906  5515
# 1907  5595
# 1908  5868
# 1909  5827
# ...    ...
# 1970  3811
# 1971  3586
# 1972  3456
# 1973  3510
# 1974  3620
# 1975  3581
# 1976  3594
# 1977  3865
# 1978  4182
# 1979  4692
# 1980  5049
# 1981  5206
# 1982  5283
# 1983  5234
# 1984  5324
# 1985  5897
# 1986  5922
# 1987  6184
# 1988  6454
# 1989  6945
# 1990  7316
# 1991  7118
# 1992  6836
# 1993  6804
# 1994  7534
# 1995  8558
# 1996  8552
# 1997  8330
# 1998  8378
# 1999  9092
#
# [120 rows x 1 columns]

# %%
live = Series()   #用于储存或者人数的Series

# %%
for i in range(int(begin),int(end)):   #
    if(str(i-1) in live.index):            #表示第i年的 前一年有数据  即不是第一年
        if(str(i - int(Life_expectancy)) in live.index):
            live[str(i)] = b[name][i] + live[str(i-1)] - b[name][i - int(Life_expectancy)]  #年份超过平均寿命的 即 有人去世了
        else:
            live[str(i)] = b[name][i] + live[str(i-1)]   #无人去世
    else:
        live[str(i)] = b[name][i]            #第一年
live.name = "num of " + name

# %%
Live_data = DataFrame(live)
Live_data.index
# Out:
# Index(['1880', '1881', '1882', '1883', '1884', '1885', '1886', '1887', '1888',
#        '1889',
#        ...
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999'],
#       dtype='object', length=120)

# %% [markdown]
# #### 实现第五问 该姓名在各年份生存人数折线图

# %%
Live_data.plot(label="bb",kind='line', rot=0,use_index = True) #用pandas 自带的plot 对这个DataFrame画图

# %% [markdown]
# ## 第六问 输入姓名A、姓名B、开始年份和结束年份，计算姓名A与姓名B出生人数的相关系数；

# %%
A = input("请输入一个姓名A ： ")
B = input("请输入一个姓名B ： ")
Names = [A,B]  #用于储存两个姓名
# Out:
# 请输入一个姓名A ： Anna
# 请输入一个姓名B ： Mary

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = input("请输入一个结束年份 ")
years = range(int(begin), int(end))

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1880
# 请输入一个结束年份 1900

# %%
t_frames = {}
for t_name in Names:
    t_frame = babyframe.loc[babyframe['Name'] == t_name]  #一个小的frame
    t_frames[t_name] = t_frame  #通过姓名存入一个小的frame

# %%
a = {}  #同第四问处理方式一样
b = {}
for key, v in t_frames.items():      #其中key 是名称 V是字典里存的Series
    a[key] = v.groupby('year').births.sum()  #对不同性别的人 求和，取得一个只有年份与人数的Series
    a[key].name = key+'_num'
    b[key] = DataFrame(a[key])  #转化为DataFrame

# %%
pieces = []   #用一个列表保存需要合并的DataFrame
for key,v in b.items():   
    pieces.append(v)
result=pd.concat(pieces,sort=True,axis=1)  #合并Frame  注意axis = 1

# %%
result.corr()  #得到姓名A与姓名B的相关系数
# Out:
#           Anna_num  Mary_num
# Anna_num  1.000000  0.981203
# Mary_num  0.981203  1.000000

# %% [markdown]
# # 第7问 输入年份，计算哪些名字是男性和女性都取的，若没有输出None，若有请按照取名总人数进行排序；

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = begin                                #默认结束年份为开始年份+1
years = range(int(begin), int(end)+1)

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1888

# %% [markdown]
# ### 通过一个Series储存 检索babyframe中 的每一个姓名 ，因为使用了Unique 不会重复检索， 然后通过每个姓名生成一个该姓名才有的dataframe ，然后查看它是否同时在Sex列中含有F或M  如果都有 就通过groupby sum 相加

# %%
unique_name = Series()
for name in babyframe['Name'].unique() :
    t = babyframe.loc[babyframe['Name'] == name]   #取出每一个名字的 DataFrame 如上
    if('F' not in t['sex'].unique() or 'M' not in t['sex'].unique()):  #如果某一个名字的 M 或F 不在它对应的DataFrame 即不是男女都取的名字
            unique_name[name] = 'None' 
    else:
            unique_name[name] = t.groupby('Name').births.sum()[0]   #根据姓名 相加 所有的性别的人数  注：groupbt得到的是一个Series 其中第0号元素为人数
Undata = DataFrame(unique_name,columns = ['Births'])
t = Undata.sort_index(axis = 1)

# %%
t  #第7问有些年份运算的时间很长
# Out:
#            Births
# Mary        11804
# Anna         5008
# Elizabeth    3236
# Emma         3104
# Margaret     2914
# Minnie       2668
# Bertha       2463
# Florence     2455
# Ethel        2386
# Bessie       2291
# Clara        2240
# Ida          2242
# Alice        2207
# Annie        2199
# Grace        2100
# Helen        1852
# Mabel        None
# Ella         1782
# Martha       1780
# Sarah        None
# Nellie       1744
# Edna         1692
# Lillian      1663
# Carrie       1653
# Laura        1635
# Pearl        1660
# Rose         1599
# Gertrude     1473
# Edith        1460
# Frances      1468
# ...           ...
# Percival     None
# Pleas        None
# Posey        None
# Powell       None
# Proctor      None
# Quincy       None
# Raliegh      None
# Rasmus       None
# Red          None
# Reid         None
# Reynolds     None
# Roe          None
# Rolly        None
# Salvador     None
# Salvatore    None
# Shed         None
# Shellie      None
# Shelton      None
# Shepherd     None
# Squire       None
# Steward      None
# Stonewall    None
# Sylvan       None
# Temple       None
# Theophilus   None
# Thorvald     None
# Tyler        None
# Vaughn       None
# Watt         None
# Winston      None
#
# [2454 rows x 1 columns]

# %% [markdown]
# ## 第八题 计算输出每个年份的男性5大常用名和女性5大常用名；

# %%
years = range(1880, 2011)    #所有年份
pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)

# %% [markdown]
# ### 此时的babyframe 包含了所有年份的所有数据

# %% [markdown]
# ### 通过检索每一年的每一个性别  然后进行排序 然后输出前5行的 某个性别 姓名人数最多

# %%
for year in babyframe['year'].unique():    
    for sex in babyframe['sex'].unique():
        sex_frame = babyframe.loc[babyframe['sex'] == sex]     #通过性别进行检索
        sex_year_frame = sex_frame.loc[sex_frame['year']== year] #通过年份检索
        sex_year_frame.sort_index(axis = 1)               #对 生成的dataframe 进行排序
        print('In the ' + str(year) + ' year.' + 'the '+ str(sex) + ' people is :' );
        print(sex_year_frame['Name'][0:5].values);
# Out:
# In the 1880 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Minnie']
# In the 1880 year.the M people is :
# ['John' 'William' 'James' 'Charles' 'George']
# In the 1881 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Margaret']
# In the 1881 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1882 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Minnie']
# In the 1882 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1883 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Minnie']
# In the 1883 year.the M people is :
# ['John' 'William' 'James' 'Charles' 'George']
# In the 1884 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Minnie']
# In the 1884 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1885 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Margaret']
# In the 1885 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1886 year.the F people is :
# ['Mary' 'Anna' 'Emma' 'Elizabeth' 'Minnie']
# In the 1886 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1887 year.the F people is :
# ['Mary' 'Anna' 'Elizabeth' 'Emma' 'Margaret']
# In the 1887 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1888 year.the F people is :
# ['Mary' 'Anna' 'Elizabeth' 'Emma' 'Margaret']
# In the 1888 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1889 year.the F people is :
# ['Mary' 'Anna' 'Elizabeth' 'Margaret' 'Emma']
# In the 1889 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1890 year.the F people is :
# ['Mary' 'Anna' 'Elizabeth' 'Margaret' 'Emma']
# In the 1890 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1891 year.the F people is :
# ['Mary' 'Anna' 'Margaret' 'Elizabeth' 'Emma']
# In the 1891 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1892 year.the F people is :
# ['Mary' 'Anna' 'Elizabeth' 'Margaret' 'Ruth']
# In the 1892 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1893 year.the F people is :
# ['Mary' 'Anna' 'Ruth' 'Margaret' 'Elizabeth']
# In the 1893 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1894 year.the F people is :
# ['Mary' 'Anna' 'Margaret' 'Helen' 'Elizabeth']
# In the 1894 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1895 year.the F people is :
# ['Mary' 'Anna' 'Helen' 'Margaret' 'Elizabeth']
# In the 1895 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1896 year.the F people is :
# ['Mary' 'Anna' 'Helen' 'Margaret' 'Ruth']
# In the 1896 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1897 year.the F people is :
# ['Mary' 'Anna' 'Helen' 'Margaret' 'Ruth']
# In the 1897 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1898 year.the F people is :
# ['Mary' 'Anna' 'Helen' 'Margaret' 'Ruth']
# In the 1898 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1899 year.the F people is :
# ['Mary' 'Anna' 'Helen' 'Margaret' 'Ruth']
# In the 1899 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1900 year.the F people is :
# ['Mary' 'Helen' 'Anna' 'Margaret' 'Ruth']
# In the 1900 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1901 year.the F people is :
# ['Mary' 'Helen' 'Anna' 'Margaret' 'Ruth']
# In the 1901 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1902 year.the F people is :
# ['Mary' 'Helen' 'Anna' 'Margaret' 'Ruth']
# In the 1902 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1903 year.the F people is :
# ['Mary' 'Helen' 'Anna' 'Margaret' 'Ruth']
# In the 1903 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1904 year.the F people is :
# ['Mary' 'Helen' 'Anna' 'Margaret' 'Ruth']
# In the 1904 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1905 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Anna' 'Ruth']
# In the 1905 year.the M people is :
# ['John' 'William' 'James' 'George' 'Charles']
# In the 1906 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Anna' 'Ruth']
# In the 1906 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1907 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Anna' 'Ruth']
# In the 1907 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1908 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Ruth' 'Anna']
# In the 1908 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1909 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Ruth' 'Dorothy']
# In the 1909 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1910 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Dorothy' 'Ruth']
# In the 1910 year.the M people is :
# ['John' 'James' 'William' 'Robert' 'George']
# In the 1911 year.the F people is :
# ['Mary' 'Helen' 'Margaret' 'Dorothy' 'Ruth']
# In the 1911 year.the M people is :
# ['John' 'William' 'James' 'George' 'Robert']
# In the 1912 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1912 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1913 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1913 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1914 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1914 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1915 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1915 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1916 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1916 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1917 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1917 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Joseph']
# In the 1918 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1918 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Charles']
# In the 1919 year.the F people is :
# ['Mary' 'Helen' 'Dorothy' 'Margaret' 'Ruth']
# In the 1919 year.the M people is :
# ['John' 'William' 'James' 'Robert' 'Charles']
# In the 1920 year.the F people is :
# ['Mary' 'Dorothy' 'Helen' 'Margaret' 'Ruth']
# In the 1920 year.the M people is :
# ['John' 'William' 'Robert' 'James' 'Charles']
# In the 1921 year.the F people is :
# ['Mary' 'Dorothy' 'Helen' 'Margaret' 'Ruth']
# In the 1921 year.the M people is :
# ['John' 'Robert' 'William' 'James' 'Charles']
# In the 1922 year.the F people is :
# ['Mary' 'Dorothy' 'Helen' 'Margaret' 'Ruth']
# In the 1922 year.the M people is :
# ['John' 'Robert' 'William' 'James' 'Charles']
# In the 1923 year.the F people is :
# ['Mary' 'Dorothy' 'Helen' 'Margaret' 'Betty']
# In the 1923 year.the M people is :
# ['John' 'Robert' 'William' 'James' 'Charles']
# In the 1924 year.the F people is :
# ['Mary' 'Dorothy' 'Helen' 'Betty' 'Margaret']
# In the 1924 year.the M people is :
# ['Robert' 'John' 'William' 'James' 'Charles']
# In the 1925 year.the F people is :
# ['Mary' 'Dorothy' 'Betty' 'Helen' 'Margaret']
# In the 1925 year.the M people is :
# ['Robert' 'John' 'William' 'James' 'Charles']
# In the 1926 year.the F people is :
# ['Mary' 'Dorothy' 'Betty' 'Helen' 'Margaret']
# In the 1926 year.the M people is :
# ['Robert' 'John' 'James' 'William' 'Charles']
# In the 1927 year.the F people is :
# ['Mary' 'Dorothy' 'Betty' 'Helen' 'Margaret']
# In the 1927 year.the M people is :
# ['Robert' 'John' 'James' 'William' 'Charles']
# In the 1928 year.the F people is :
# ['Mary' 'Betty' 'Dorothy' 'Helen' 'Margaret']
# In the 1928 year.the M people is :
# ['Robert' 'John' 'James' 'William' 'Charles']
# In the 1929 year.the F people is :
# ['Mary' 'Betty' 'Dorothy' 'Helen' 'Margaret']
# In the 1929 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Charles']
# In the 1930 year.the F people is :
# ['Mary' 'Betty' 'Dorothy' 'Helen' 'Margaret']
# In the 1930 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1931 year.the F people is :
# ['Mary' 'Betty' 'Dorothy' 'Barbara' 'Joan']
# In the 1931 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1932 year.the F people is :
# ['Mary' 'Betty' 'Barbara' 'Dorothy' 'Joan']
# In the 1932 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1933 year.the F people is :
# ['Mary' 'Betty' 'Barbara' 'Dorothy' 'Joan']
# In the 1933 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1934 year.the F people is :
# ['Mary' 'Betty' 'Barbara' 'Shirley' 'Dorothy']
# In the 1934 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1935 year.the F people is :
# ['Mary' 'Shirley' 'Barbara' 'Betty' 'Patricia']
# In the 1935 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1936 year.the F people is :
# ['Mary' 'Shirley' 'Barbara' 'Betty' 'Patricia']
# In the 1936 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1937 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Shirley' 'Betty']
# In the 1937 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1938 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Betty' 'Shirley']
# In the 1938 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1939 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Betty' 'Shirley']
# In the 1939 year.the M people is :
# ['Robert' 'James' 'John' 'William' 'Richard']
# In the 1940 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Judith' 'Betty']
# In the 1940 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1941 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Carol' 'Linda']
# In the 1941 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1942 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Linda' 'Carol']
# In the 1942 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1943 year.the F people is :
# ['Mary' 'Barbara' 'Patricia' 'Linda' 'Carol']
# In the 1943 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1944 year.the F people is :
# ['Mary' 'Barbara' 'Linda' 'Patricia' 'Carol']
# In the 1944 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1945 year.the F people is :
# ['Mary' 'Linda' 'Barbara' 'Patricia' 'Carol']
# In the 1945 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1946 year.the F people is :
# ['Mary' 'Linda' 'Patricia' 'Barbara' 'Carol']
# In the 1946 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1947 year.the F people is :
# ['Linda' 'Mary' 'Patricia' 'Barbara' 'Sandra']
# In the 1947 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Richard']
# In the 1948 year.the F people is :
# ['Linda' 'Mary' 'Barbara' 'Patricia' 'Susan']
# In the 1948 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'David']
# In the 1949 year.the F people is :
# ['Linda' 'Mary' 'Patricia' 'Barbara' 'Susan']
# In the 1949 year.the M people is :
# ['James' 'Robert' 'John' 'William' 'Michael']
# In the 1950 year.the F people is :
# ['Linda' 'Mary' 'Patricia' 'Barbara' 'Susan']
# In the 1950 year.the M people is :
# ['James' 'Robert' 'John' 'Michael' 'David']
# In the 1951 year.the F people is :
# ['Linda' 'Mary' 'Patricia' 'Deborah' 'Barbara']
# In the 1951 year.the M people is :
# ['James' 'Robert' 'John' 'Michael' 'David']
# In the 1952 year.the F people is :
# ['Linda' 'Mary' 'Patricia' 'Deborah' 'Susan']
# In the 1952 year.the M people is :
# ['James' 'Robert' 'John' 'Michael' 'David']
# In the 1953 year.the F people is :
# ['Mary' 'Linda' 'Deborah' 'Patricia' 'Susan']
# In the 1953 year.the M people is :
# ['Robert' 'James' 'Michael' 'John' 'David']
# In the 1954 year.the F people is :
# ['Mary' 'Linda' 'Deborah' 'Patricia' 'Susan']
# In the 1954 year.the M people is :
# ['Michael' 'James' 'Robert' 'John' 'David']
# In the 1955 year.the F people is :
# ['Mary' 'Deborah' 'Linda' 'Debra' 'Susan']
# In the 1955 year.the M people is :
# ['Michael' 'David' 'James' 'Robert' 'John']
# In the 1956 year.the F people is :
# ['Mary' 'Debra' 'Linda' 'Deborah' 'Susan']
# In the 1956 year.the M people is :
# ['Michael' 'James' 'Robert' 'David' 'John']
# In the 1957 year.the F people is :
# ['Mary' 'Susan' 'Linda' 'Debra' 'Karen']
# In the 1957 year.the M people is :
# ['Michael' 'James' 'David' 'Robert' 'John']
# In the 1958 year.the F people is :
# ['Mary' 'Susan' 'Linda' 'Karen' 'Patricia']
# In the 1958 year.the M people is :
# ['Michael' 'David' 'James' 'Robert' 'John']
# In the 1959 year.the F people is :
# ['Mary' 'Susan' 'Linda' 'Karen' 'Donna']
# In the 1959 year.the M people is :
# ['Michael' 'David' 'James' 'John' 'Robert']
# In the 1960 year.the F people is :
# ['Mary' 'Susan' 'Linda' 'Karen' 'Donna']
# In the 1960 year.the M people is :
# ['David' 'Michael' 'James' 'John' 'Robert']
# In the 1961 year.the F people is :
# ['Mary' 'Lisa' 'Susan' 'Linda' 'Karen']
# In the 1961 year.the M people is :
# ['Michael' 'David' 'John' 'James' 'Robert']
# In the 1962 year.the F people is :
# ['Lisa' 'Mary' 'Susan' 'Karen' 'Linda']
# In the 1962 year.the M people is :
# ['Michael' 'David' 'John' 'James' 'Robert']
# In the 1963 year.the F people is :
# ['Lisa' 'Mary' 'Susan' 'Karen' 'Linda']
# In the 1963 year.the M people is :
# ['Michael' 'John' 'David' 'James' 'Robert']
# In the 1964 year.the F people is :
# ['Lisa' 'Mary' 'Susan' 'Karen' 'Patricia']
# In the 1964 year.the M people is :
# ['Michael' 'John' 'David' 'James' 'Robert']
# In the 1965 year.the F people is :
# ['Lisa' 'Mary' 'Karen' 'Kimberly' 'Susan']
# In the 1965 year.the M people is :
# ['Michael' 'John' 'David' 'James' 'Robert']
# In the 1966 year.the F people is :
# ['Lisa' 'Kimberly' 'Mary' 'Michelle' 'Karen']
# In the 1966 year.the M people is :
# ['Michael' 'David' 'James' 'John' 'Robert']
# In the 1967 year.the F people is :
# ['Lisa' 'Kimberly' 'Michelle' 'Mary' 'Susan']
# In the 1967 year.the M people is :
# ['Michael' 'David' 'James' 'John' 'Robert']
# In the 1968 year.the F people is :
# ['Lisa' 'Michelle' 'Kimberly' 'Jennifer' 'Melissa']
# In the 1968 year.the M people is :
# ['Michael' 'David' 'John' 'James' 'Robert']
# In the 1969 year.the F people is :
# ['Lisa' 'Michelle' 'Jennifer' 'Kimberly' 'Melissa']
# In the 1969 year.the M people is :
# ['Michael' 'David' 'James' 'John' 'Robert']
# In the 1970 year.the F people is :
# ['Jennifer' 'Lisa' 'Kimberly' 'Michelle' 'Amy']
# In the 1970 year.the M people is :
# ['Michael' 'James' 'David' 'John' 'Robert']
# In the 1971 year.the F people is :
# ['Jennifer' 'Michelle' 'Lisa' 'Kimberly' 'Amy']
# In the 1971 year.the M people is :
# ['Michael' 'James' 'David' 'John' 'Robert']
# In the 1972 year.the F people is :
# ['Jennifer' 'Michelle' 'Lisa' 'Kimberly' 'Amy']
# In the 1972 year.the M people is :
# ['Michael' 'Christopher' 'James' 'David' 'John']
# In the 1973 year.the F people is :
# ['Jennifer' 'Amy' 'Michelle' 'Kimberly' 'Lisa']
# In the 1973 year.the M people is :
# ['Michael' 'Christopher' 'Jason' 'James' 'David']
# In the 1974 year.the F people is :
# ['Jennifer' 'Amy' 'Michelle' 'Heather' 'Angela']
# In the 1974 year.the M people is :
# ['Michael' 'Jason' 'Christopher' 'David' 'James']
# In the 1975 year.the F people is :
# ['Jennifer' 'Amy' 'Heather' 'Melissa' 'Angela']
# In the 1975 year.the M people is :
# ['Michael' 'Jason' 'Christopher' 'James' 'David']
# In the 1976 year.the F people is :
# ['Jennifer' 'Amy' 'Melissa' 'Heather' 'Angela']
# In the 1976 year.the M people is :
# ['Michael' 'Jason' 'Christopher' 'David' 'James']
# In the 1977 year.the F people is :
# ['Jennifer' 'Melissa' 'Amy' 'Jessica' 'Heather']
# In the 1977 year.the M people is :
# ['Michael' 'Jason' 'Christopher' 'David' 'James']
# In the 1978 year.the F people is :
# ['Jennifer' 'Melissa' 'Jessica' 'Amy' 'Heather']
# In the 1978 year.the M people is :
# ['Michael' 'Jason' 'Christopher' 'David' 'James']
# In the 1979 year.the F people is :
# ['Jennifer' 'Melissa' 'Amanda' 'Jessica' 'Amy']
# In the 1979 year.the M people is :
# ['Michael' 'Christopher' 'Jason' 'David' 'James']
# In the 1980 year.the F people is :
# ['Jennifer' 'Amanda' 'Jessica' 'Melissa' 'Sarah']
# In the 1980 year.the M people is :
# ['Michael' 'Christopher' 'Jason' 'David' 'James']
# In the 1981 year.the F people is :
# ['Jennifer' 'Jessica' 'Amanda' 'Sarah' 'Melissa']
# In the 1981 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Jason' 'David']
# In the 1982 year.the F people is :
# ['Jennifer' 'Jessica' 'Amanda' 'Sarah' 'Melissa']
# In the 1982 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Jason' 'David']
# In the 1983 year.the F people is :
# ['Jennifer' 'Jessica' 'Amanda' 'Ashley' 'Sarah']
# In the 1983 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'David' 'Joshua']
# In the 1984 year.the F people is :
# ['Jennifer' 'Jessica' 'Ashley' 'Amanda' 'Sarah']
# In the 1984 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'David']
# In the 1985 year.the F people is :
# ['Jessica' 'Ashley' 'Jennifer' 'Amanda' 'Sarah']
# In the 1985 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Daniel']
# In the 1986 year.the F people is :
# ['Jessica' 'Ashley' 'Amanda' 'Jennifer' 'Sarah']
# In the 1986 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'David']
# In the 1987 year.the F people is :
# ['Jessica' 'Ashley' 'Amanda' 'Jennifer' 'Sarah']
# In the 1987 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'David']
# In the 1988 year.the F people is :
# ['Jessica' 'Ashley' 'Amanda' 'Sarah' 'Jennifer']
# In the 1988 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Andrew']
# In the 1989 year.the F people is :
# ['Jessica' 'Ashley' 'Brittany' 'Amanda' 'Sarah']
# In the 1989 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'David']
# In the 1990 year.the F people is :
# ['Jessica' 'Ashley' 'Brittany' 'Amanda' 'Samantha']
# In the 1990 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Daniel']
# In the 1991 year.the F people is :
# ['Ashley' 'Jessica' 'Brittany' 'Amanda' 'Samantha']
# In the 1991 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Andrew']
# In the 1992 year.the F people is :
# ['Ashley' 'Jessica' 'Amanda' 'Brittany' 'Sarah']
# In the 1992 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Andrew']
# In the 1993 year.the F people is :
# ['Jessica' 'Ashley' 'Sarah' 'Samantha' 'Emily']
# In the 1993 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Tyler']
# In the 1994 year.the F people is :
# ['Jessica' 'Ashley' 'Emily' 'Samantha' 'Sarah']
# In the 1994 year.the M people is :
# ['Michael' 'Christopher' 'Matthew' 'Joshua' 'Tyler']
# In the 1995 year.the F people is :
# ['Jessica' 'Ashley' 'Emily' 'Samantha' 'Sarah']
# In the 1995 year.the M people is :
# ['Michael' 'Matthew' 'Christopher' 'Jacob' 'Joshua']
# In the 1996 year.the F people is :
# ['Emily' 'Jessica' 'Ashley' 'Sarah' 'Samantha']
# In the 1996 year.the M people is :
# ['Michael' 'Matthew' 'Jacob' 'Christopher' 'Joshua']
# In the 1997 year.the F people is :
# ['Emily' 'Jessica' 'Ashley' 'Sarah' 'Hannah']
# In the 1997 year.the M people is :
# ['Michael' 'Jacob' 'Matthew' 'Christopher' 'Joshua']
# In the 1998 year.the F people is :
# ['Emily' 'Hannah' 'Samantha' 'Ashley' 'Sarah']
# In the 1998 year.the M people is :
# ['Michael' 'Jacob' 'Matthew' 'Joshua' 'Christopher']
# In the 1999 year.the F people is :
# ['Emily' 'Hannah' 'Alexis' 'Sarah' 'Samantha']
# In the 1999 year.the M people is :
# ['Jacob' 'Michael' 'Matthew' 'Joshua' 'Nicholas']
# In the 2000 year.the F people is :
# ['Emily' 'Hannah' 'Madison' 'Ashley' 'Sarah']
# In the 2000 year.the M people is :
# ['Jacob' 'Michael' 'Matthew' 'Joshua' 'Christopher']
# In the 2001 year.the F people is :
# ['Emily' 'Madison' 'Hannah' 'Ashley' 'Alexis']
# In the 2001 year.the M people is :
# ['Jacob' 'Michael' 'Matthew' 'Joshua' 'Christopher']
# In the 2002 year.the F people is :
# ['Emily' 'Madison' 'Hannah' 'Emma' 'Alexis']
# In the 2002 year.the M people is :
# ['Jacob' 'Michael' 'Joshua' 'Matthew' 'Ethan']
# In the 2003 year.the F people is :
# ['Emily' 'Emma' 'Madison' 'Hannah' 'Olivia']
# In the 2003 year.the M people is :
# ['Jacob' 'Michael' 'Joshua' 'Matthew' 'Andrew']
# In the 2004 year.the F people is :
# ['Emily' 'Emma' 'Madison' 'Olivia' 'Hannah']
# In the 2004 year.the M people is :
# ['Jacob' 'Michael' 'Joshua' 'Matthew' 'Ethan']
# In the 2005 year.the F people is :
# ['Emily' 'Emma' 'Madison' 'Abigail' 'Olivia']
# In the 2005 year.the M people is :
# ['Jacob' 'Michael' 'Joshua' 'Matthew' 'Ethan']
# In the 2006 year.the F people is :
# ['Emily' 'Emma' 'Madison' 'Isabella' 'Ava']
# In the 2006 year.the M people is :
# ['Jacob' 'Michael' 'Joshua' 'Ethan' 'Matthew']
# In the 2007 year.the F people is :
# ['Emily' 'Isabella' 'Emma' 'Ava' 'Madison']
# In the 2007 year.the M people is :
# ['Jacob' 'Michael' 'Ethan' 'Joshua' 'Daniel']
# In the 2008 year.the F people is :
# ['Emma' 'Isabella' 'Emily' 'Olivia' 'Ava']
# In the 2008 year.the M people is :
# ['Jacob' 'Michael' 'Ethan' 'Joshua' 'Daniel']
# In the 2009 year.the F people is :
# ['Isabella' 'Emma' 'Olivia' 'Sophia' 'Ava']
# In the 2009 year.the M people is :
# ['Jacob' 'Ethan' 'Michael' 'Alexander' 'William']
# In the 2010 year.the F people is :
# ['Isabella' 'Sophia' 'Emma' 'Olivia' 'Ava']
# In the 2010 year.the M people is :
# ['Jacob' 'Ethan' 'Michael' 'Jayden' 'William']

# %%
#运行时间很长

# %%
begin = input("请输入一个开始年份： ")  #先输入开始结束年份 取得一个DataFrame
end  = input("请输入一个结束年份 ")
years = range(int(begin), int(end))

pieces = []
columns = ['Name', 'sex', 'births']

for year in years:
    path = 'babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
babyframe = pd.concat(pieces, ignore_index=True)
# Out:
# 请输入一个开始年份： 1880
# 请输入一个结束年份 1882

# %%
t1 = babyframe.loc[babyframe['Name'] == 'Mary']   #取出每一个名字的 DataFrame 如上
t2 = babyframe.loc[babyframe['Name'] == 'Anna']   #取出每一个名字的 DataFrame 如上
t2
# Out:
#       Name sex  births  year
# 1     Anna   F    2604  1880
# 1470  Anna   M      12  1880
# 2001  Anna   F    2698  1881
# 3368  Anna   M      16  1881

# %%
x2 = t2.groupby('year').births.sum()
x2.name = 'Anna'
tx2 = DataFrame(x2)
tx2
# Out:
#       Anna
# year
# 1880  2616
# 1881  2714

# %%
tx2.T
# Out:
# year  1880  1881
# Anna  2616  2714

# %%
x1 = t1.groupby('year').births.sum()
x1.name = 'Mary'
tx1 = DataFrame(x1)
tx1.T
# Out:
# year  1880  1881
# Mary  7092  6948

# %%
result=pd.concat([tx1.T,tx2.T],sort=True)  #合并Frame  注意axis = 1 
result
# Out:
# year  1880  1881
# Mary  7092  6948
# Anna  2616  2714

# %%
babyframe['births']
# Out:
# 0       7065
# 1       2604
# 2       2003
# 3       1939
# 4       1746
# 5       1578
# 6       1472
# 7       1414
# 8       1320
# 9       1288
# 10      1258
# 11      1226
# 12      1156
# 13      1063
# 14      1045
# 15      1040
# 16      1012
# 17       995
# 18       982
# 19       949
# 20       858
# 21       808
# 22       794
# 23       793
# 24       787
# 25       783
# 26       769
# 27       768
# 28       704
# 29       700
#         ...
# 1970       5
# 1971       5
# 1972       5
# 1973       5
# 1974       5
# 1975       5
# 1976       5
# 1977       5
# 1978       5
# 1979       5
# 1980       5
# 1981       5
# 1982       5
# 1983       5
# 1984       5
# 1985       5
# 1986       5
# 1987       5
# 1988       5
# 1989       5
# 1990       5
# 1991       5
# 1992       5
# 1993       5
# 1994       5
# 1995       5
# 1996       5
# 1997       5
# 1998       5
# 1999       5
# Name: births, Length: 2000, dtype: int64

# %%
a = list(babyframe['Name'])
# Out:
# ['Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Minnie',
#  'Margaret',
#  'Ida',
#  'Alice',
#  'Bertha',
#  'Sarah',
#  'Annie',
#  'Clara',
#  'Ella',
#  'Florence',
#  'Cora',
#  'Martha',
#  'Laura',
#  'Nellie',
#  'Grace',
#  'Carrie',
#  'Maude',
#  'Mabel',
#  'Bessie',
#  'Jennie',
#  'Gertrude',
#  'Julia',
#  'Hattie',
#  'Edith',
#  'Mattie',
#  'Rose',
#  'Catherine',
#  'Lillian',
#  'Ada',
#  'Lillie',
#  'Helen',
#  'Jessie',
#  'Louise',
#  'Ethel',
#  'Lula',
#  'Myrtle',
#  'Eva',
#  'Frances',
#  'Lena',
#  'Lucy',
#  'Edna',
#  'Maggie',
#  'Pearl',
#  'Daisy',
#  'Fannie',
#  'Josephine',
#  'Dora',
#  'Rosa',
#  'Katherine',
#  'Agnes',
#  'Marie',
#  'Nora',
#  'May',
#  'Mamie',
#  'Blanche',
#  'Stella',
#  'Ellen',
#  'Nancy',
#  'Effie',
#  'Sallie',
#  'Nettie',
#  'Della',
#  'Lizzie',
#  'Flora',
#  'Susie',
#  'Maud',
#  'Mae',
#  'Etta',
#  'Harriet',
#  'Sadie',
#  'Caroline',
#  'Katie',
#  'Lydia',
#  'Elsie',
#  'Kate',
#  'Susan',
#  'Mollie',
#  'Alma',
#  'Addie',
#  'Georgia',
#  'Eliza',
#  'Lulu',
#  'Nannie',
#  'Lottie',
#  'Amanda',
#  'Belle',
#  'Charlotte',
#  'Rebecca',
#  'Ruth',
#  'Viola',
#  'Olive',
#  'Amelia',
#  'Hannah',
#  'Jane',
#  'Virginia',
#  'Emily',
#  'Matilda',
#  'Irene',
#  'Kathryn',
#  'Esther',
#  'Willie',
#  'Henrietta',
#  'Ollie',
#  'Amy',
#  'Rachel',
#  'Sara',
#  'Estella',
#  'Theresa',
#  'Augusta',
#  'Ora',
#  'Pauline',
#  'Josie',
#  'Lola',
#  'Sophia',
#  'Leona',
#  'Anne',
#  'Mildred',
#  'Ann',
#  'Beulah',
#  'Callie',
#  'Lou',
#  'Delia',
#  'Eleanor',
#  'Barbara',
#  'Iva',
#  'Louisa',
#  'Maria',
#  'Mayme',
#  'Evelyn',
#  'Estelle',
#  'Nina',
#  'Betty',
#  'Marion',
#  'Bettie',
#  'Dorothy',
#  'Luella',
#  'Inez',
#  'Lela',
#  'Rosie',
#  'Allie',
#  'Millie',
#  'Janie',
#  'Cornelia',
#  'Victoria',
#  'Ruby',
#  'Winifred',
#  'Alta',
#  'Celia',
#  'Christine',
#  'Beatrice',
#  'Birdie',
#  'Harriett',
#  'Mable',
#  'Myra',
#  'Sophie',
#  'Tillie',
#  'Isabel',
#  'Sylvia',
#  'Carolyn',
#  'Isabelle',
#  'Leila',
#  'Sally',
#  'Ina',
#  'Essie',
#  'Bertie',
#  'Nell',
#  'Alberta',
#  'Katharine',
#  'Lora',
#  'Rena',
#  'Mina',
#  'Rhoda',
#  'Mathilda',
#  'Abbie',
#  'Eula',
#  'Dollie',
#  'Hettie',
#  'Eunice',
#  'Fanny',
#  'Ola',
#  'Lenora',
#  'Adelaide',
#  'Christina',
#  'Lelia',
#  'Nelle',
#  'Sue',
#  'Johanna',
#  'Lilly',
#  'Lucinda',
#  'Minerva',
#  'Lettie',
#  'Roxie',
#  'Cynthia',
#  'Helena',
#  'Hilda',
#  'Hulda',
#  'Bernice',
#  'Genevieve',
#  'Jean',
#  'Cordelia',
#  'Marian',
#  'Francis',
#  'Jeanette',
#  'Adeline',
#  'Gussie',
#  'Leah',
#  'Lois',
#  'Lura',
#  'Mittie',
#  'Hallie',
#  'Isabella',
#  'Olga',
#  'Phoebe',
#  'Teresa',
#  'Hester',
#  'Lida',
#  'Lina',
#  'Winnie',
#  'Claudia',
#  'Marguerite',
#  'Vera',
#  'Cecelia',
#  'Bess',
#  'Emilie',
#  'John',
#  'Rosetta',
#  'Verna',
#  'Myrtie',
#  'Cecilia',
#  'Elva',
#  'Olivia',
#  'Ophelia',
#  'Georgie',
#  'Elnora',
#  'Violet',
#  'Adele',
#  'Lily',
#  'Linnie',
#  'Loretta',
#  'Madge',
#  'Polly',
#  'Virgie',
#  'Eugenia',
#  'Lucile',
#  'Lucille',
#  'Mabelle',
#  'Rosalie',
#  'Kittie',
#  'Meta',
#  'Angie',
#  'Dessie',
#  'Georgiana',
#  'Lila',
#  'Regina',
#  'Selma',
#  'Wilhelmina',
#  'Bridget',
#  'Lilla',
#  'Malinda',
#  'Vina',
#  'Freda',
#  'Gertie',
#  'Jeannette',
#  'Louella',
#  'Mandy',
#  'Roberta',
#  'Cassie',
#  'Corinne',
#  'Ivy',
#  'Melissa',
#  'Lyda',
#  'Naomi',
#  'Norma',
#  'Bell',
#  'Margie',
#  'Nona',
#  'Zella',
#  'Dovie',
#  'Elvira',
#  'Erma',
#  'Irma',
#  'Leota',
#  'William',
#  'Artie',
#  'Blanch',
#  'Charity',
#  'Janet',
#  'Lorena',
#  'Lucretia',
#  'Orpha',
#  'Alvina',
#  'Annette',
#  'Catharine',
#  'Elma',
#  'Geneva',
#  'Lee',
#  'Leora',
#  'Lona',
#  'Miriam',
#  'Zora',
#  'Linda',
#  'Octavia',
#  'Sudie',
#  'Zula',
#  'Adella',
#  'Alpha',
#  'Frieda',
#  'George',
#  'Joanna',
#  'Leonora',
#  'Priscilla',
#  'Tennie',
#  'Angeline',
#  'Docia',
#  'Ettie',
#  'Flossie',
#  'Hanna',
#  'Letha',
#  'Minta',
#  'Retta',
#  'Rosella',
#  'Adah',
#  'Berta',
#  'Elisabeth',
#  'Elise',
#  'Goldie',
#  'Leola',
#  'Margret',
#  'Adaline',
#  'Floy',
#  'Idella',
#  'Juanita',
#  'Lenna',
#  'Lucie',
#  'Missouri',
#  'Nola',
#  'Zoe',
#  'Eda',
#  'Isabell',
#  'James',
#  'Julie',
#  'Letitia',
#  'Madeline',
#  'Malissa',
#  'Mariah',
#  'Pattie',
#  'Vivian',
#  'Almeda',
#  'Aurelia',
#  'Claire',
#  'Dolly',
#  'Hazel',
#  'Jannie',
#  'Kathleen',
#  'Kathrine',
#  'Lavinia',
#  'Marietta',
#  'Melvina',
#  'Ona',
#  'Pinkie',
#  'Samantha',
#  'Susanna',
#  'Chloe',
#  'Donnie',
#  'Elsa',
#  'Gladys',
#  'Matie',
#  'Pearle',
#  'Vesta',
#  'Vinnie',
#  'Antoinette',
#  'Clementine',
#  'Edythe',
#  'Harriette',
#  'Libbie',
#  'Lilian',
#  'Lue',
#  'Lutie',
#  'Magdalena',
#  'Meda',
#  'Rita',
#  'Tena',
#  'Zelma',
#  'Adelia',
#  'Annetta',
#  'Antonia',
#  'Dona',
#  'Elizebeth',
#  'Georgianna',
#  'Gracie',
#  'Iona',
#  'Lessie',
#  'Leta',
#  'Liza',
#  'Mertie',
#  'Molly',
#  'Neva',
#  'Oma',
#  'Alida',
#  'Alva',
#  'Cecile',
#  'Cleo',
#  'Donna',
#  'Ellie',
#  'Ernestine',
#  'Evie',
#  'Frankie',
#  'Helene',
#  'Minna',
#  'Myrta',
#  'Prudence',
#  'Queen',
#  'Rilla',
#  'Savannah',
#  'Tessie',
#  'Tina',
#  'Agatha',
#  'America',
#  'Anita',
#  'Arminta',
#  'Dorothea',
#  'Ira',
#  'Luvenia',
#  'Marjorie',
#  'Maybelle',
#  'Mellie',
#  'Nan',
#  'Pearlie',
#  'Sidney',
#  'Velma',
#  'Clare',
#  'Constance',
#  'Dixie',
#  'Ila',
#  'Iola',
#  'Jimmie',
#  'Louvenia',
#  'Lucia',
#  'Ludie',
#  'Luna',
#  'Metta',
#  'Patsy',
#  'Phebe',
#  'Sophronia',
#  'Adda',
#  'Avis',
#  'Betsy',
#  'Bonnie',
#  'Cecil',
#  'Cordie',
#  'Emmaline',
#  'Ethelyn',
#  'Hortense',
#  'June',
#  'Louie',
#  'Lovie',
#  'Marcella',
#  'Melinda',
#  'Mona',
#  'Odessa',
#  'Veronica',
#  'Aimee',
#  'Annabel',
#  'Ava',
#  'Bella',
#  'Carolina',
#  'Cathrine',
#  'Christena',
#  'Clyde',
#  'Dena',
#  'Dolores',
#  'Eleanore',
#  'Elmira',
#  'Fay',
#  'Frank',
#  'Jenny',
#  'Kizzie',
#  'Lonnie',
#  'Loula',
#  'Magdalene',
#  'Mettie',
#  'Mintie',
#  'Peggy',
#  'Reba',
#  'Serena',
#  'Vida',
#  'Zada',
#  'Abigail',
#  'Celestine',
#  'Celina',
#  'Claudie',
#  'Clemmie',
#  'Connie',
#  'Daisie',
#  'Deborah',
#  'Dessa',
#  'Easter',
#  'Eddie',
#  'Emelia',
#  'Emmie',
#  'Imogene',
#  'India',
#  'Jeanne',
#  'Joan',
#  'Lenore',
#  'Liddie',
#  'Lotta',
#  'Mame',
#  'Nevada',
#  'Rachael',
#  'Sina',
#  'Willa',
#  'Aline',
#  'Beryl',
#  'Charles',
#  'Daisey',
#  'Dorcas',
#  'Edmonia',
#  'Effa',
#  'Eldora',
#  'Eloise',
#  'Emmer',
#  'Era',
#  'Gena',
#  'Henry',
#  'Iris',
#  'Izora',
#  'Lennie',
#  'Lissie',
#  'Mallie',
#  'Malvina',
#  'Mathilde',
#  'Mazie',
#  'Queenie',
#  'Robert',
#  'Rosina',
#  'Salome',
#  'Theodora',
#  'Therese',
#  'Vena',
#  'Wanda',
#  'Wilda',
#  'Altha',
#  'Anastasia',
#  'Besse',
#  'Bird',
#  'Birtie',
#  'Clarissa',
#  'Claude',
#  'Delilah',
#  'Diana',
#  'Emelie',
#  'Erna',
#  'Fern',
#  'Florida',
#  'Frona',
#  'Hilma',
#  'Joseph',
#  'Juliet',
#  'Leonie',
#  'Lugenia',
#  'Mammie',
#  'Manda',
#  'Manerva',
#  'Manie',
#  'Nella',
#  'Paulina',
#  'Philomena',
#  'Rae',
#  'Selina',
#  'Sena',
#  'Theodosia',
#  'Tommie',
#  'Una',
#  'Vernie',
#  'Adela',
#  'Althea',
#  'Amalia',
#  'Amber',
#  'Angelina',
#  'Annabelle',
#  'Anner',
#  'Arie',
#  'Clarice',
#  'Corda',
#  'Corrie',
#  'Dell',
#  'Dellar',
#  'Donie',
#  'Doris',
#  'Elda',
#  'Elinor',
#  'Emeline',
#  'Emilia',
#  'Esta',
#  'Estell',
#  'Etha',
#  'Fred',
#  'Hope',
#  'Indiana',
#  'Ione',
#  'Jettie',
#  'Johnnie',
#  'Josiephine',
#  'Kitty',
#  'Lavina',
#  'Leda',
#  'Letta',
#  'Mahala',
#  'Marcia',
#  'Margarette',
#  'Maudie',
#  'Maye',
#  'Norah',
#  'Oda',
#  'Patty',
#  'Paula',
#  'Permelia',
#  'Rosalia',
#  'Roxanna',
#  'Sula',
#  'Vada',
#  'Winnifred',
#  'Adline',
#  'Almira',
#  'Alvena',
#  'Arizona',
#  'Becky',
#  'Bennie',
#  'Bernadette',
#  'Camille',
#  'Cordia',
#  'Corine',
#  'Dicie',
#  'Dove',
#  'Drusilla',
#  'Elena',
#  'Elenora',
#  'Elmina',
#  'Ethyl',
#  'Evalyn',
#  'Evelina',
#  'Faye',
#  'Huldah',
#  'Idell',
#  'Inga',
#  'Irena',
#  'Jewell',
#  'Kattie',
#  'Lavenia',
#  'Leslie',
#  'Lovina',
#  'Lulie',
#  'Magnolia',
#  'Margeret',
#  'Margery',
#  'Media',
#  'Millicent',
#  'Nena',
#  'Ocie',
#  'Orilla',
#  'Osie',
#  'Pansy',
#  'Ray',
#  'Rosia',
#  'Rowena',
#  'Shirley',
#  'Tabitha',
#  'Thomas',
#  'Verdie',
#  'Walter',
#  'Zetta',
#  'Zoa',
#  'Zona',
#  'Albertina',
#  'Albina',
#  'Alyce',
#  'Amie',
#  'Angela',
#  'Annis',
#  'Carol',
#  'Carra',
#  'Clarence',
#  'Clarinda',
#  'Delphia',
#  'Dillie',
#  'Doshie',
#  'Drucilla',
#  'Etna',
#  'Eugenie',
#  'Eulalia',
#  'Eve',
#  'Felicia',
#  'Florance',
#  'Fronie',
#  'Geraldine',
#  'Gina',
#  'Glenna',
#  'Grayce',
#  'Hedwig',
#  'Jessica',
#  'Jossie',
#  'Katheryn',
#  'Katy',
#  'Lea',
#  'Leanna',
#  'Leitha',
#  'Leone',
#  'Lidie',
#  'Loma',
#  'Lular',
#  'Magdalen',
#  'Maymie',
#  'Minervia',
#  'Muriel',
#  'Neppie',
#  'Olie',
#  'Onie',
#  'Osa',
#  'Otelia',
#  'Paralee',
#  'Patience',
#  'Rella',
#  'Rillie',
#  'Rosanna',
#  'Theo',
#  'Tilda',
#  'Tishie',
#  'Tressa',
#  'Viva',
#  'Yetta',
#  'Zena',
#  'Zola',
#  'Abby',
#  'Aileen',
#  'Alba',
#  'Alda',
#  'Alla',
#  'Alverta',
#  'Ara',
#  'Ardelia',
#  'Ardella',
#  'Arrie',
#  'Arvilla',
#  'Augustine',
#  'Aurora',
#  'Bama',
#  'Bena',
#  'Byrd',
#  'Calla',
#  'Camilla',
#  'Carey',
#  'Carlotta',
#  'Celestia',
#  'Cherry',
#  'Cinda',
#  'Classie',
#  'Claudine',
#  'Clemie',
#  'Clifford',
#  'Clyda',
#  'Creola',
#  'Debbie',
#  'Dee',
#  'Dinah',
#  'Doshia',
#  'Ednah',
#  'Edyth',
#  'Eleanora',
#  'Electa',
#  'Eola',
#  'Erie',
#  'Eudora',
#  'Euphemia',
#  'Evalena',
#  'Evaline',
#  'Faith',
#  'Fidelia',
#  'Freddie',
#  'Golda',
#  'Harry',
#  'Helma',
#  'Hermine',
#  'Hessie',
#  'Ivah',
#  'Janette',
#  'Jennette',
#  'Joella',
#  'Kathryne',
#  'Lacy',
#  'Lanie',
#  'Lauretta',
#  'Leana',
#  'Leatha',
#  'Leo',
#  'Liller',
#  'Lillis',
#  'Louetta',
#  'Madie',
#  'Mai',
#  'Martina',
#  'Maryann',
#  'Melva',
#  'Mena',
#  'Mercedes',
#  'Merle',
#  'Mima',
#  'Minda',
#  'Monica',
#  'Nealie',
#  'Netta',
#  'Nolia',
#  'Nonie',
#  'Odelia',
#  'Ottilie',
#  'Phyllis',
#  'Robbie',
#  'Sabina',
#  'Sada',
#  'Sammie',
#  'Suzanne',
#  'Sybilla',
#  'Thea',
#  'Tressie',
#  'Vallie',
#  'Venie',
#  'Viney',
#  'Wilhelmine',
#  'Winona',
#  'Zelda',
#  'Zilpha',
#  'Adelle',
#  'Adina',
#  'Adrienne',
#  'Albertine',
#  'Alys',
#  'Ana',
#  'Araminta',
#  'Arthur',
#  'Birtha',
#  'Bulah',
#  'Caddie',
#  'Celie',
#  'Charlotta',
#  'Clair',
#  'Concepcion',
#  'Cordella',
#  'Corrine',
#  'Delila',
#  'Delphine',
#  'Dosha',
#  'Edgar',
#  'Elaine',
#  'Elisa',
#  'Ellar',
#  'Elmire',
#  'Elvina',
#  'Ena',
#  'Estie',
#  'Etter',
#  'Fronnie',
#  'Genie',
#  'Georgina',
#  'Glenn',
#  'Gracia',
#  'Guadalupe',
#  'Gwendolyn',
#  'Hassie',
#  'Honora',
#  'Icy',
#  'Isa',
#  'Isadora',
#  'Jesse',
#  'Jewel',
#  'Joe',
#  'Johannah',
#  'Juana',
#  'Judith',
#  'Judy',
#  'Junie',
#  'Lavonia',
#  'Lella',
#  'Lemma',
#  'Letty',
#  'Linna',
#  'Littie',
#  'Lollie',
#  'Lorene',
#  'Louis',
#  'Love',
#  'Lovisa',
#  'Lucina',
#  'Lynn',
#  'Madora',
#  'Mahalia',
#  'Manervia',
#  'Manuela',
#  'Margarett',
#  'Margaretta',
#  'Margarita',
#  'Marilla',
#  'Mignon',
#  'Mozella',
#  'Natalie',
#  'Nelia',
#  'Nolie',
#  'Omie',
#  'Opal',
#  'Ossie',
#  'Ottie',
#  'Ottilia',
#  'Parthenia',
#  'Penelope',
#  'Pinkey',
#  'Pollie',
#  'Rennie',
#  'Reta',
#  'Roena',
#  'Rosalee',
#  'Roseanna',
#  'Ruthie',
#  'Sabra',
#  'Sannie',
#  'Selena',
#  'Sibyl',
#  'Tella',
#  'Tempie',
#  'Tennessee',
#  'Teressa',
#  'Texas',
#  'Theda',
#  'Thelma',
#  'Thursa',
#  'Ula',
#  'Vannie',
#  'Verona',
#  'Vertie',
#  'Wilma',
#  'John',
#  'William',
#  'James',
#  'Charles',
#  'George',
#  'Frank',
#  'Joseph',
#  'Thomas',
#  'Henry',
#  'Robert',
#  'Edward',
#  'Harry',
#  'Walter',
#  'Arthur',
#  'Fred',
#  'Albert',
#  'Samuel',
#  'David',
#  'Louis',
#  'Joe',
#  'Charlie',
#  'Clarence',
#  'Richard',
#  'Andrew',
#  'Daniel',
#  'Ernest',
#  'Will',
#  'Jesse',
#  'Oscar',
#  'Lewis',
#  'Peter',
#  'Benjamin',
#  'Frederick',
#  'Willie',
#  'Alfred',
#  'Sam',
#  'Roy',
#  'Herbert',
#  'Jacob',
#  'Tom',
#  'Elmer',
#  'Carl',
#  'Lee',
#  'Howard',
#  'Martin',
#  'Michael',
#  'Bert',
#  'Herman',
#  'Jim',
#  'Francis',
#  'Harvey',
#  'Earl',
#  'Eugene',
#  'Ralph',
#  'Ed',
#  'Claude',
#  'Edwin',
#  'Ben',
#  ...]
